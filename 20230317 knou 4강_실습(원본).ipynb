# %%
cd /content/drive/MyDrive/Colab Notebooks/GitHub-Colab
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/GitHub-Colab'
# /content

# %% [markdown]
# # 4강 1절
# - 2023.3.17(금) 실습

# %%
3.141592
# Out:
# 3.141592

# %%
"I am Eunice ^^"
# Out:
# 'I am Eunice ^^'

# %%
# “Hello World!”
"Hello World!"
# Out:
# 'Hello World!'

# %%
5 / 3
# Out:
# 1.6666666666666667

# %%
5 % 3
# Out:
# 2

# %%
"computer" + "*" * 2 + "science"
# Out:
# 'computer**science'

# %%
2 * 7
# Out:
# 14

# %%
print(2 * 7)
# Out:
# 14

# %% [markdown]
# ## ✔️ print() 함수 실습

# %%
"""
echo 기능 vs print() 함수
"""
"hello world,"
"Python is fun!"
# Out:
# 'Python is fun!'

# %%
# print() 함수로 여러 줄의 결과 출력
print("hello world,")
print("Python is fun!")
# Out:
# hello world,
# Python is fun!

# %% [markdown]
# # 4강 2절
# - 2023.3.20(월) 실습

# %%
print(1 / 3 * 3.14 * 20 ** 2 * 30 )
print(3.14 * 20 ** 2 + 3.14 * 20 * 30)
# Out:
# 12559.999999999998
# 3140.0

# %%
# 변수 생성 및 할당
rad = 20
hei = 30

print(1 / 3 * 3.14 * rad ** 2 * hei)
print(3.14 * rad ** 2 + 3.14 * rad * hei)
# Out:
# 12559.999999999998
# 3140.0

# %% [markdown]
# # 4강 3절
# - 2023.3.20(월) 실습

# %%
5 / 2
# Out:
# 2.5

# %%
# 정수 나눗셈 연산자
5 // 2
# Out:
# 2

# %%
round(3.56)
# Out:
# 4

# %%
round(3.14)
# Out:
# 3

# %%
abs(-2.12)
# Out:
# 2.12

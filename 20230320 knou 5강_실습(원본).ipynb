# %% [markdown]
# # 5강 2절
# - 2023.3.20(월) 실습

# %% [markdown]
# 삼각형 출력하기

# %% [markdown]
# 원뿔 계산 프로그램 개선

# %%
#반지름, 높이 값 할당
rad = 20
hei = 30
#부피 출력
print(1 / 3 * 3.14 * rad ** 2 * hei)
#겉넓이 출력
print(3.14 * rad ** 2 + 3.14 * rad * hei)

# %%
#반지름, 높이 값 할당
rad = 20
hei = 30
#부피 출력
print(1 / 3 * 3.14 * rad ** 2 * hei)
#겉넓이 출력
print(3.14 * rad ** 2 + 3.14 * rad * hei)

# %% [markdown]
# # 출석수업 과제물
# - 2023.3.23(월) 수행

# %%
sum = 0
for i in range (1, 10):
  sum += i
print(sum)
# Out:
# 45

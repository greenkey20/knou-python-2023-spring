# %% [markdown]
# # 9강 1절

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Colab Notebooks/GitHub-Colab
# Out:
# /content/drive/MyDrive/Colab Notebooks/GitHub-Colab

# %%
cd /content/drive/MyDrive/Colab Notebooks/GitHub-Colab/knou-python-2023-spring
# Out:
# /content/drive/MyDrive/Colab Notebooks/GitHub-Colab/knou-python-2023-spring

# %%
# !git config --global user.email 'greenkey20@gmail.com'
# !git config --global user.name 'greenkey20'

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git restore --staged <file>..." to unstage)
# 	modified:   "20230418 knou 7\341\204\200\341\205\241\341\206\274_\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270(\341\204\213\341\205\257\341\206\253\341\204\207\341\205\251\341\206\253).ipynb"
# 	new file:   "20230427 knou 9\341\204\200\341\205\241\341\206\274_\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270(\341\204\213\341\205\257\341\206\253\341\204\207\341\205\251\341\206\253).ipynb"

# %%
# !git add .

# %%
# !git commit -m "feat: add python basics practices [functions]"
# Out:
# [main e63070d] feat: add python basics practices [functions]
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite "20230418 knou 7\341\204\200\341\205\241\341\206\274_\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270(\341\204\213\341\205\257\341\206\253\341\204\207\341\205\251\341\206\253).ipynb" (95%)
#  create mode 100644 "20230427 knou 9\341\204\200\341\205\241\341\206\274_\341\204\211\341\205\265\341\206\257\341\204\211\341\205\263\341\206\270(\341\204\213\341\205\257\341\206\253\341\204\207\341\205\251\341\206\253).ipynb"

# %%
# !git push origin main
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 5.60 KiB | 1.12 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/greenkey20/knou-python-2023-spring.git
#    e1aa7c4..e63070d  main -> main

# %%
# !git status
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %% [markdown]
# **원뿔 부피 계산 함수 정의**

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/.git/

# %%
if rad > 0 and hei > 0 :
    # r, h 모두 양수일 때
    vol = 1/3 * 3.14 * rad ** 2 * hei
    print("원뿔의 부피는", vol, "입니다.")
else :
  # r, h가 음수일 때
  print("반지름과 높이 값에 양수를 입력하세요")

# %% [markdown]
# **원뿔 부피 계산 함수 호출**

# %% [markdown]
# ### 11h50 v1 은영 실습

# %%
def prt_cone_vol(r, h) :
    if r > 0 and h > 0 :
        vol = 1 / 3 * 3.14 * r ** 2 * h
        print("원뿔의 부피는", vol, "입니다")
    else :
        print("반지름과 높이 값에 양수를 입력하세요")
# Out:
# 반지름을 입력하세요 > 10
# 높이를 입력하세요 > 5
# 원뿔의 부피는 523.3333333333333 입니다

# %%
rad = float(input("반지름을 입력하세요 > "))
hei = float(input("높이를 입력하세요 > "))
prt_cone_vol(rad, hei)
# Out:
# 반지름을 입력하세요 > 6
# 높이를 입력하세요 > -9
# 반지름과 높이 값에 양수를 입력하세요

# %% [markdown]
# **숫자를 입력받고 역순으로 출력하는 함수를 사용한 프로그램 문제**

# %% [markdown]
# ### 12h v1 수업 듣기 전 실습

# %%
def prt_reverse_num1(n) :
    n_list = list(n) # google '파이썬 문자열 문자로 나누기' = list() 함수의 인자로 문자열을 전달하면 문자 단위로 나누어 list에 저장됨
    n_list_reversed = n_list[-1: : -1] # google '파이썬 리스트 순서 뒤집기' = list slicing 사용해서 list 원소들의 순서 뒤집기 -> 원본 리스트는 바뀌지 않음
    print("매개변수로 받은 문자열을 리스트로 만든 것 = ", n_list)
    print("n_list의 순서를 뒤집은 리스트 = ", n_list_reversed)
    for n in n_list_reversed :
        print(n, end = "")
# Out:
# 숫자 하나를 입력해 주세요 > 1234.5667
# 매개변수로 받은 문자열을 리스트로 만든 것 =  ['1', '2', '3', '4', '.', '5', '6', '6', '7']
# n_list의 순서를 뒤집은 리스트 =  ['7', '6', '6', '5', '.', '4', '3', '2', '1']
# 7665.4321

# %%
num_str = input("숫자 하나를 입력해 주세요(소수점 가능) > ")
prt_reverse_num1(num_str)

# %% [markdown]
# ### 12h30 수업 초반 듣고 실습

# %%
def prt_reverse_num2(n) :
    while (n > 0) :
        print(n % 10, end="")
        n //= 10

# %%
num_int = int(input("정수 하나를 입력해 주세요 > "))
prt_reverse_num2(num_int)
# Out:
# 정수 하나를 입력해 주세요 > 1234
# 4321

# %% [markdown]
# # 9강 2절

# %% [markdown]
# ### 14h25 v1 은영 실습

# %% [markdown]
# **원뿔 부피 계산 결과 반환 함수 정의**

# %%
# 이 코드 블록을 한 번 실행해야지만 이 함수가 정의되었다고 인식함 vs otherwise 정의되지 않은 함수로써 error 발생
def rtn_cone_vol(rad, hei) :
    if rad > 0 and hei > 0 : # rad, hei 모두 양수일 때
        vol = 1/3 * 3.14 * rad ** 2 * hei
        return vol
    else : # rad 또는 hei가 음수일 때
        print("반지름과 높이 값에 양수를 입력하세요")

# %%
def format_float_left(vol) :
    return format(vol, "<20.4f")

# %%
def format_float_right(vol) :
    return format(vol, ">20.4f")

# %%
rad = float(input("반지름을 입력하세요 > "))
hei = float(input("높이를 입력하세요 > "))

vol = rtn_cone_vol(rad, hei)
print("반지름 ", rad, ", 높이 ", hei, "인 원뿔의 부피는 ", vol, "이군요!", sep="")
print("반지름 ", rad, ", 높이 ", hei, "인 원뿔의 부피는 ", format_float_left(vol), "이군요!", sep="")

print("vol = ", vol, sep="")
print("vol = ", format_float_right(vol), sep="")
# Out:
# 반지름을 입력하세요 > 3
# 높이를 입력하세요 > 6
# 반지름 3.0, 높이 6.0인 원뿔의 부피는 56.519999999999996이군요!
# 반지름 3.0, 높이 6.0인 원뿔의 부피는 56.5200             이군요!
# vol = 56.519999999999996
# vol =              56.5200

# %% [markdown]
# ### 15h v1 은영 실습

# %% [markdown]
# **원뿔 부피 및 겉넓이 반환 함수 정의**

# %%
def rtn_cone_vol_n_surf(rad, hei) :
    if rad > 0 and hei > 0 : # rad, hei 모두 양수일 때
        vol = 1/3 * 3.14 * rad ** 2 * hei
        surf = 3.14 * rad ** 2 + 3.14 * rad * hei
        return vol, surf
    else : # rad 또는 hei가 음수일 때
        print("반지름과 높이 값에 양수를 입력하세요")

# %%
rad = 20
hei = 30

vol, surf = rtn_cone_vol_n_surf(rad, hei)
print("반지름 ", rad, ", 높이 ", hei, "인 원뿔의 부피 = ", format_float_left(vol), ", 겉넓이 = ", format_float_right(surf), sep="")
# Out:
# 반지름 20, 높이 30인 원뿔의 부피 = 12560.0000          , 겉넓이 =            3140.0000

# %% [markdown]
# **세 개의 사용자 입력을 오름차순으로 정렬하는 함수를 이용하여 정렬된 값을 출력하는 문제**

# %% [markdown]
# ### 15h10 v1 은영 실습

# %%
def sort3_v1(a, b, c) :
    if (a < b) : # 파이썬에서는 조건절에 괄호 필요 없음
        if (b < c) :
            size1, size2, size3 = a, b, c
        else :
            if (a < c) :
                size1, size2, size3 = a, c, b
            else :
                size1, size2, size3 = c, a, b
    else :
        if (b > c) :
            size1, size2, size3 = c, b, a
        else : 
            if (a < c) :
                size1, size2, size3 = b, a, c
            else :
                size1, size2, size3 = b, c, a

    return size1, size2, size3

# %% [markdown]
# ### 15h35 수업 들은 후 v2 은영 실습
# 파이썬의 동시할당 개념을 활용하여 보다 더 간단한 방법으로 풀어볼 수 있음

# %%
def sort3_v2(a, b, c) :
    if a > b :
        a, b = b, a
    if a > c :
        a, c = c, a
    if b > c :
        b, c = c, b
    
    print("v2 정렬 결과 =", a, b, c)

# %%
a = int(input("첫번째 숫자를 입력하세요: "))
b = int(input("두번째 숫자를 입력하세요: "))
c = int(input("세번째 숫자를 입력하세요: "))

print("v1 정렬 결과 =", sort3_v1(a, b, c)) # v1 정렬 결과 = (5, 7, 10)
sort3_v2(a, b, c) # v2 정렬 결과 = 5 7 10

print("입력했던 숫자들 =", a, b, c) # 입력했던 숫자들 = 10 5 7
# Out:
# 첫번째 숫자를 입력하세요: 10
# 두번째 숫자를 입력하세요: 5
# 세번째 숫자를 입력하세요: 7
# v1 정렬 결과 = (5, 7, 10)
# v2 정렬 결과 = 5 7 10
# 입력했던 숫자들 = 10 5 7

# %% [markdown]
# # 9강 3절

# %% [markdown]
# **값의 전달**
#
# 강의 슬라이드에 있는 코드 실행시켜보기

# %% [markdown]
# **변수의 스코프**
#
# 강의 슬라이드에 있는 코드 실행시켜보기

# %% [markdown]
# **단위 원뿔(반지름 20, 높이 30)의 부피와 겉넓이를 출력하는 문제**

# %% [markdown]
# ### 16h55 v1 은영 실습

# %%
# 원뿔 계산 함수 정의
def rtn_cone_vol_surf(r = 20, h = 30) :
    if r > 0 and h > 0 :
        # r, h 모두 양수일 때
        return 1/3 * 3.14 * r ** 2 * h, 3.14 * r ** 2 + 3.14 * r * h
    else :
        # r, h가 음수일 때
        print("반지름과 높이 값에 양수를 입력하세요")

print(rtn_cone_vol_surf(100, 80))
print(rtn_cone_vol_surf())
# Out:
# (837333.3333333333, 56520.0)
# (12559.999999999998, 3140.0)

# %% [markdown]
# **여러개의 수를 입력받고 합과 평균을 반환하는 var_sum_avg 함수를 사용하여, (20, 25, 10, 85, 100, 150)에 대한 합과 평균을 출력하는 프로그램을 작성하시오.**

# %% [markdown]
# ### 17h v1 은영 실습

# %%
def var_sum_avg(*nums) :
    sum = 0
    for num in nums :
        sum += num
    avg = sum / len(nums) # 교수님께서는 count 변수 하나 만드셔서 for문 돌 때마다 계수하심
    return sum, avg

# %%
sum, avg = var_sum_avg(20, 25, 10, 85, 100, 150)
print("합 = ", sum, ", 평균 = ", avg, sep="")
# Out:
# 합 = 390, 평균 = 65.0
